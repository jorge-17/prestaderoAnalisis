# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import sum, avg,col,first,when,udf,regexp_replace,to_timestamp
from pyspark.sql.types import StringType, DoubleType, ArrayType
import re
ss = SparkSession.builder.config("spark.jars", "/home/jrodarte/postgresql-42.7.3.jar").getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/09/02 19:13:42 WARN Utils: Your hostname, jrodarte-ThinkPad-T480, resolves to a loopback address: 127.0.1.1; using 192.168.100.13 instead (on interface wlp3s0)
# 25/09/02 19:13:42 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 25/09/02 19:13:44 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
dfMovimientos = ss.read.format("csv").options(header='true', inferSchema='true', delimiter=',').load("documentos/movimientos0725.csv")
#dfMovimientos.schema
# Out:
# StructType([StructField('Autorización', IntegerType(), True), StructField('Fecha operación', StringType(), True), StructField('Tipo', StringType(), True), StructField('Movimiento', StringType(), True), StructField('Importe', StringType(), True), StructField('Estatus', StringType(), True), StructField('Ref. 1', StringType(), True), StructField('Detalle', StringType(), True)])

# %%
# Datos de conexión
user = "jrodarte"
password = "roma1993_"

dfTipoMovimientos = ss.read.format("jdbc") \
    .option("url", "jdbc:postgresql://localhost:5432/postgres") \
    .option("dbtable", "(select * from prestadero.tipomovimientos)") \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "org.postgresql.Driver") \
    .load()

#dfTipoMovimientos.show()
# Out:
# +----------------+--------------+
# |idtipomovimiento|tipomovimiento|
# +----------------+--------------+
# |               1|        FONDEO|
# |               2|         PAGOS|
# |               3|      COMISION|
# |               4|     RETENCION|
# |               5|         ABONO|
# +----------------+--------------+

# %%
def limpiarImporte(importe):
    return importe.replace("$", "").replace(",", "")


print(limpiarImporte('$0.00'))
limpiarImpoUDF = udf(limpiarImporte, StringType())
# Out:
# 0.00

# %%
nuevosNombresMov = ['autorizacion', 'feoperacion', 'tipo', 'movimiento', 'importe', 'estatus', 'referencia']
nuevosNombresDetMov = ['autorizacion', 'detalle']
dfDetalleMovimiento = dfMovimientos.select('Autorización', 'Detalle')
dfMovimientos = dfMovimientos.selectExpr(
    "`Autorización`",
    "`Fecha operación`",
    "`Tipo`",
    "`Movimiento`",
    "`Importe`",
    "`Estatus`",
    "`Ref. 1`"
)

# %%
dfMovimientos = dfMovimientos.toDF(*nuevosNombresMov)
dfMovimientos = dfMovimientos.withColumn('feoperacion', to_timestamp(col("feoperacion"), "dd/MM/yyyy HH:mm:ss"))
dfMovimientos = dfMovimientos.withColumn('importeS', limpiarImpoUDF(col("importe")))
dfMovimientos = dfMovimientos.withColumn('importe', col("importeS").cast(DoubleType())).drop("importeS")
dfDetalleMovimiento = dfDetalleMovimiento.toDF(*nuevosNombresDetMov)
#dfMovimientos.show()
#dfMovimientos.schema
# Out:
# +------------+-------------------+-----+----------+-------+--------+--------------------+
# |autorizacion|        feoperacion| tipo|movimiento|importe| estatus|          referencia|
# +------------+-------------------+-----+----------+-------+--------+--------------------+
# |   103124028|2025-07-31 17:06:19|PAGOS|     PAGOS|    0.0|APLICADO|PAGO DE: HARVEY RUIZ|
# |   103105326|2025-07-31 16:58:03|PAGOS|     PAGOS|   0.01|APLICADO|     PAGO DE: GMORIN|
# |   103077947|2025-07-31 10:46:32|PAGOS|     PAGOS|  11.17|APLICADO|     PAGO DE: PORUGA|
# |   103077946|2025-07-31 10:46:32|PAGOS| RETENCION|    0.0|APLICADO|       RETENCION ISR|
# |   103077945|2025-07-31 10:46:32|PAGOS| RETENCION|    0.0|APLICADO|       RETENCION IVA|
# |   102992053|2025-07-30 13:46:03|PAGOS| RETENCION|    0.0|APLICADO|       RETENCION ISR|
# |   102992052|2025-07-30 13:46:03|PAGOS| RETENCION|    0.0|APLICADO|       RETENCION IVA|
# |   102992054|2025-07-30 13:46:03|PAGOS|     PAGOS|  13.99|APLICADO|       PAGO DE: MNK@|
# |   102975097|2025-07-30 11:01:14|PAGOS|     PAGOS|    2.4|APLICADO|     PAGO DE: GMORIN|
# |   102975096|2025-07-30 11:01:14|PAGOS| RETENCION|    0.0|APLICADO|       RETENCION ISR|
# |   102975095|2025-07-30 11:01:14|PAGOS| RETENCION|    0.0|APLICADO|       RETENCION IVA|
# |   102887958|2025-07-29 10:51:04|PAGOS|     PAGOS|  22.87|APLICADO|PAGO DE: EDUARDO ...|
# |   102887748|2025-07-29 10:50:57|PAGOS|     PAGOS|  11.43|APLICADO|PAGO DE: EDUARDO ...|
# |   102871405|2025-07-29 10:45:14|PAGOS| RETENCION|    0.0|APLICADO|       RETENCION IVA|
# |   102871406|2025-07-29 10:45:14|PAGOS| RETENCION|    0.0|APLICADO|       RETENCION ISR|
# |   102871408|2025-07-29 10:45:14|PAGOS|     PAGOS|  22.53|APLICADO|   PAGO DE: DIANA GR|
# |   102842901|2025-07-28 22:45:15|PAGOS|     PAGOS|   0.06|APLICADO|     PAGO DE: PORUGA|
# |   102775278|2025-07-27 11:51:28|PAGOS|     PAGOS|  21.48|APLICADO|     PAGO DE: CETSMX|
# |   102750655|2025-07-25 14:31:24|PAGOS|     PAGOS|  45.74|APLICADO| PAGO DE: SALAS VIRI|
# |   102750654|2025-07-25 14:31:24|PAGOS| RETENCION|    0.0|APLICADO|       RETENCION ISR|
# +------------+-------------------+-----+----------+-------+--------+--------------------+
# only showing top 20 rows
# StructType([StructField('autorizacion', IntegerType(), True), StructField('feoperacion', TimestampType(), True), StructField('tipo', StringType(), True), StructField('movimiento', StringType(), True), StructField('importe', DoubleType(), True), StructField('estatus', StringType(), True), StructField('referencia', StringType(), True)])

# %%
dfMovimientos = dfMovimientos.join(dfTipoMovimientos, dfMovimientos.movimiento == dfTipoMovimientos.tipomovimiento, "inner")
dfMovimientos = dfMovimientos.drop('tipomovimiento').drop('movimiento')
#dfMovimientos.schema
# Out:
# StructType([StructField('autorizacion', IntegerType(), True), StructField('feoperacion', TimestampType(), True), StructField('tipo', StringType(), True), StructField('importe', DoubleType(), True), StructField('estatus', StringType(), True), StructField('referencia', StringType(), True), StructField('idtipomovimiento', IntegerType(), True)])

# %%
dfMovimientos.write \
    .format("jdbc") \
    .option("url", "jdbc:postgresql://localhost:5432/postgres") \
    .option("dbtable", "prestadero.movimientos") \
    .option("user", "jrodarte") \
    .option("password", "roma1993_") \
    .option("driver", "org.postgresql.Driver") \
    .mode("append") \
    .save()

# %%
dfDetalleMovimiento.show()
# Out:
# +------------+--------------------+
# |autorizacion|             detalle|
# +------------+--------------------+
# |   104924819|                NULL|
# |   104924820|                NULL|
# |   104924821|Principal:4.04683...|
# |   104923175|                NULL|
# |   104923176|                NULL|
# |   104923177|Principal:3.09670...|
# |   104859707|Principal:0.00000...|
# |   104732052|                NULL|
# |   104732053|                NULL|
# |   104732054|Principal:10.4385...|
# |   104673705|                NULL|
# |   104673706|                NULL|
# |   104673707|Principal:0.00000...|
# |   104636402|Principal:10.6304...|
# |   104635868|Principal:5.31522...|
# |   104634793|Principal:8.68985...|
# |   104579832|Principal:12.4996...|
# |   104551730|Principal:17.5966...|
# |   104536750|Principal:24.0733...|
# |   104530273|Principal:17.8160...|
# +------------+--------------------+
# only showing top 20 rows

# %%
ptrDigitos = r"\d\s"
ptrEspacioFinal = r"\s$"
def limpiezaDetalleMov(detalleMov):
    if detalleMov is None:
        return []
    else:
        coincidencia = re.findall(ptrDigitos, detalleMov)
        lenCoincidencia = len(coincidencia)
        arrDetalle = re.split(ptrDigitos, detalleMov)
        
        return arrDetalle

limpiezaDetalleMovUDF = udf(limpiezaDetalleMov, ArrayType(StringType()))

# %%
dfDetalleMovimiento = dfDetalleMovimiento.withColumn('arrDetalle', limpiezaDetalleMovUDF(dfDetalleMovimiento.detalle))
dfDetalleMovimiento.show()
#dfDetalleMovimiento.write.mode('overwrite').csv('Proyectos/prestadero/detalleMov.csv')
# Out:
# +------------+--------------------+--------------------+
# |autorizacion|             detalle|          arrDetalle|
# +------------+--------------------+--------------------+
# |   104924819|                NULL|                  []|
# |   104924820|                NULL|                  []|
# |   104924821|Principal:4.04683...|[Principal:4.0468...|
# |   104923175|                NULL|                  []|
# |   104923176|                NULL|                  []|
# |   104923177|Principal:3.09670...|[Principal:3.0967...|
# |   104859707|Principal:0.00000...|[Principal:0.0000...|
# |   104732052|                NULL|                  []|
# |   104732053|                NULL|                  []|
# |   104732054|Principal:10.4385...|[Principal:10.438...|
# |   104673705|                NULL|                  []|
# |   104673706|                NULL|                  []|
# |   104673707|Principal:0.00000...|[Principal:0.0000...|
# |   104636402|Principal:10.6304...|[Principal:10.630...|
# |   104635868|Principal:5.31522...|[Principal:5.3152...|
# |   104634793|Principal:8.68985...|[Principal:8.6898...|
# |   104579832|Principal:12.4996...|[Principal:12.499...|
# |   104551730|Principal:17.5966...|[Principal:17.596...|
# |   104536750|Principal:24.0733...|[Principal:24.073...|
# |   104530273|Principal:17.8160...|[Principal:17.816...|
# +------------+--------------------+--------------------+
# only showing top 20 rows

# %%
def procesarDetalleMov(aut,arrDetalle):
    arrDetalleNuevo = []
    for i in arrDetalle:
        Autitem = ("autorizacion", aut)
        Conitem = ("concepto", i.split(':')[0])
        Monitem = ("monto", i.split(':')[1])
        arrDetalleNuevo.append([Autitem,Conitem,Monitem])

    dictDetalleNuevo = dict(arrDetalleNuevo)
    return dictDetalleNuevo

# %%
procesarDetalleMov(103124028,["Principal: 0.0000", "Interes: 0.0000", "Impuesto Interes:  0.0000", "Moratorios: 0.0028",  "Impuesto Moratorios: 0.0004", "IVA Comisión Moratorios:  0.00000"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[227], line 1
# ----> 1 procesarDetalleMov(103124028,["Principal: 0.0000", "Interes: 0.0000", "Impuesto Interes:  0.0000", "Moratorios: 0.0028",  "Impuesto Moratorios: 0.0004", "IVA Comisión Moratorios:  0.00000"])
#
# Cell In[226], line 9, in procesarDetalleMov(aut, arrDetalle)
#       6     Monitem = ("monto", i.split(':')[1])
#       7     arrDetalleNuevo.append([Autitem,Conitem,Monitem])
# ----> 9 dictDetalleNuevo = dict(arrDetalleNuevo)
#      10 return dictDetalleNuevo
#
# ValueError: dictionary update sequence element #0 has length 3; 2 is required
